# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
vg = pd.read_csv("VGSales.csv")

# %%
vg.head()
# Out:
#        Year_of_Release     NA_Sales     EU_Sales     JP_Sales  Other_Sales
# count      6536.000000  6536.000000  6536.000000  6536.000000  6536.000000  \
# mean       2007.347307     0.364030     0.213670     0.064204     0.075840
# std           4.181052     0.897245     0.646888     0.290985     0.259418
# min        1985.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2004.000000     0.060000     0.020000     0.000000     0.010000
# 50%        2007.000000     0.150000     0.060000     0.000000     0.020000
# 75%        2010.000000     0.380000     0.200000     0.010000     0.070000
# max        2016.000000    41.360000    28.960000     6.500000    10.570000
#
#        Global_Sales  Critic_Score  Critic_Count   User_Score   User_Count
# count   6536.000000   6536.000000   6536.000000  6536.000000  6536.000000
# mean       0.717916     70.493574     28.228733     7.273853   107.822674
# std        1.856836     12.954194     17.980194     1.285212   231.485516
# min        0.010000     29.000000      3.000000     3.000000     4.000000
# 25%        0.110000     62.000000     14.000000     6.600000    11.000000
# 50%        0.290000     72.000000     24.000000     7.500000    26.000000
# 75%        0.730000     80.000000     39.000000     8.200000    81.000000
# max       82.530000     98.000000     86.000000     9.600000  1739.000000

# %%
vg.describe()
# Out:
#        Year_of_Release     NA_Sales     EU_Sales     JP_Sales  Other_Sales
# count      6536.000000  6536.000000  6536.000000  6536.000000  6536.000000  \
# mean       2007.347307     0.364030     0.213670     0.064204     0.075840
# std           4.181052     0.897245     0.646888     0.290985     0.259418
# min        1985.000000     0.000000     0.000000     0.000000     0.000000
# 25%        2004.000000     0.060000     0.020000     0.000000     0.010000
# 50%        2007.000000     0.150000     0.060000     0.000000     0.020000
# 75%        2010.000000     0.380000     0.200000     0.010000     0.070000
# max        2016.000000    41.360000    28.960000     6.500000    10.570000
#
#        Global_Sales  Critic_Score  Critic_Count   User_Score   User_Count
# count   6536.000000   6536.000000   6536.000000  6536.000000  6536.000000
# mean       0.717916     70.493574     28.228733     7.273853   107.822674
# std        1.856836     12.954194     17.980194     1.285212   231.485516
# min        0.010000     29.000000      3.000000     3.000000     4.000000
# 25%        0.110000     62.000000     14.000000     6.600000    11.000000
# 50%        0.290000     72.000000     24.000000     7.500000    26.000000
# 75%        0.730000     80.000000     39.000000     8.200000    81.000000
# max       82.530000     98.000000     86.000000     9.600000  1739.000000

# %%
# Line Graph of Genres and their sales through the years
plt.figure(figsize=(15, 10))
ax = sns.lineplot(x = 'Year_of_Release', y = 'Global_Sales', hue = 'Genre', data = vg.reset_index(),
                  err_style=None, palette='bright')
ax.figure.set_size_inches(22, 8)
ax.set_title('Genre Popularity from 1985-2016', fontsize=24)
ax.set_xlabel('Year', fontsize=18)
ax.set_ylabel('Global Sales (Millions)', fontsize=18)
plt.legend(loc = 'upper right', fontsize = 12)
plt.show()

# %%
# Pie Graph of Revenue by Area
areas = [vg['NA_Sales'].sum(), vg['EU_Sales'].sum(), vg['JP_Sales'].sum(), vg['Other_Sales'].sum()]
labels = ['North America', 'Europe', 'Japan', 'Rest of the World']
explode = [0.05, 0.05, 0.05, 0.05]
plt.pie(areas, labels= labels, shadow=True, autopct = '%.1f%%', startangle=50, explode = explode)
plt.title("Video Game Sales Revenue by Area")
plt.show()

# %%
#Create DF from 1990-1999 (90s)
vg90s = vg.loc[(vg["Year_of_Release"] >= 1990) & (vg["Year_of_Release"] <= 1999)].copy()
vg90s
# Out:
#                        Name Platform  Year_of_Release         Genre
# 22             Gran Turismo       PS           1997.0        Racing  \
# 27        Final Fantasy VII       PS           1997.0  Role-Playing
# 28           Gran Turismo 2       PS           1999.0        Racing
# 39       Final Fantasy VIII       PS           1999.0  Role-Playing
# 47                 Tekken 3       PS           1998.0      Fighting
# ...                     ...      ...              ...           ...
# 5869  Saiyuki: Journey West       PS           1999.0      Strategy
# 5873              StarCraft       PC           1998.0      Strategy
# 6089    Planescape: Torment       PC           1998.0  Role-Playing
# 6318              Homeworld       PC           1998.0      Strategy
# 6411    The Longest Journey       PC           1999.0     Adventure
#
#                         Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 22    Sony Computer Entertainment      4.02      3.87      2.54         0.52  \
# 27    Sony Computer Entertainment      3.01      2.47      3.28         0.96
# 28    Sony Computer Entertainment      3.88      3.42      1.69         0.50
# 39                     SquareSoft      2.28      1.72      3.63         0.23
# 47    Sony Computer Entertainment      3.27      2.22      1.40         0.29
# ...                           ...       ...       ...       ...          ...
# 5869                   Tecmo Koei      0.03      0.02      0.00         0.00
# 5873                   Activision      0.00      0.04      0.00         0.01
# 6089                    Interplay      0.01      0.02      0.00         0.00
# 6318                Vivendi Games      0.00      0.02      0.00         0.00
# 6411           Empire Interactive      0.00      0.01      0.00         0.00
#
#       Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count
# 22           10.95          96.0          16.0         8.7       138.0  \
# 27            9.72          92.0          20.0         9.2      1282.0
# 28            9.49          93.0          23.0         9.0       135.0
# 39            7.86          90.0          24.0         8.6       644.0
# 47            7.16          96.0          15.0         9.1       367.0
# ...            ...           ...           ...         ...         ...
# 5869          0.05          73.0           9.0         7.1         9.0
# 5873          0.05          88.0          15.0         9.1       813.0
# 6089          0.03          91.0          22.0         9.2       813.0
# 6318          0.02          93.0          20.0         9.0       326.0
# 6411          0.02          91.0          26.0         8.9       439.0
#
#                    Developer Rating
# 22         Polyphony Digital      E
# 27                SquareSoft      T
# 28         Polyphony Digital      T
# 39                SquareSoft      T
# 47                     Namco      T
# ...                      ...    ...
# 5869                    Koei      E
# 5873  Blizzard Entertainment      T
# 6089      Black Isle Studios      T
# 6318                   Relic      E
# 6411                  Funcom      M
#
# [74 rows x 16 columns]

# %%
#Create DF from 2000-2009
vg00s = vg.loc[(vg["Year_of_Release"] >= 2000) & (vg["Year_of_Release"] < 2010)].copy()
vg00s
# Out:
#                                 Name Platform  Year_of_Release     Genre
# 0                         Wii Sports      Wii           2006.0    Sports  \
# 1                     Mario Kart Wii      Wii           2008.0    Racing
# 2                  Wii Sports Resort      Wii           2009.0    Sports
# 3              New Super Mario Bros.       DS           2006.0  Platform
# 4                           Wii Play      Wii           2006.0      Misc
# ...                              ...      ...              ...       ...
# 6526        Legacy of Kain: Defiance       PC           2003.0    Action
# 6527                           Trine       PC           2009.0    Action
# 6528                   Karnaaj Rally      GBA           2003.0    Racing
# 6530                 Hospital Tycoon       PC           2007.0  Strategy
# 6532  Mortal Kombat: Deadly Alliance      GBA           2002.0  Fighting
#
#               Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 0              Nintendo     41.36     28.96      3.77         8.45  \
# 1              Nintendo     15.68     12.76      3.79         3.29
# 2              Nintendo     15.61     10.93      3.28         2.95
# 3              Nintendo     11.28      9.14      6.50         2.88
# 4              Nintendo     13.96      9.18      2.93         2.84
# ...                 ...       ...       ...       ...          ...
# 6526  Eidos Interactive      0.00      0.01      0.00         0.00
# 6527            Nobilis      0.00      0.01      0.00         0.00
# 6528             Jaleco      0.01      0.00      0.00         0.00
# 6530        Codemasters      0.00      0.01      0.00         0.00
# 6532       Midway Games      0.01      0.00      0.00         0.00
#
#       Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count
# 0            82.53          76.0          51.0         8.0       322.0  \
# 1            35.52          82.0          73.0         8.3       709.0
# 2            32.77          80.0          73.0         8.0       192.0
# 3            29.80          89.0          65.0         8.5       431.0
# 4            28.92          58.0          41.0         6.6       129.0
# ...            ...           ...           ...         ...         ...
# 6526          0.01          70.0          11.0         8.7        67.0
# 6527          0.01          80.0          50.0         8.2       488.0
# 6528          0.01          81.0           9.0         9.5         4.0
# 6530          0.01          51.0           8.0         3.8        29.0
# 6532          0.01          81.0          12.0         8.8         9.0
#
#                        Developer Rating
# 0                       Nintendo      E
# 1                       Nintendo      E
# 2                       Nintendo      E
# 3                       Nintendo      E
# 4                       Nintendo      E
# ...                          ...    ...
# 6526             Nixxes Software      M
# 6527            Frozenbyte, Inc.   E10+
# 6528  Infinite Dreams, Paragon 5      E
# 6530            Big Red Software   E10+
# 6532             Criterion Games      M
#
# [4474 rows x 16 columns]

# %%
#Create DF from 2010-2016
vg10s = vg.loc[vg["Year_of_Release"] >= 2010].copy()
vg10s
# Out:
#                                    Name Platform  Year_of_Release     Genre
# 8                    Kinect Adventures!     X360           2010.0      Misc  \
# 15           Call of Duty: Black Ops II      PS3           2012.0   Shooter
# 18                         Mario Kart 7      3DS           2011.0    Racing
# 19              Call of Duty: Black Ops      PS3           2010.0   Shooter
# 23                  Super Mario 3D Land      3DS           2011.0  Platform
# ...                                 ...      ...              ...       ...
# 6529           Sébastien Loeb Rally Evo     XOne           2016.0    Racing
# 6531                   Fast Racing Neo      WiiU           2016.0    Action
# 6533  Metal Gear Solid V: Ground Zeroes       PC           2014.0    Action
# 6534                             Breach       PC           2011.0   Shooter
# 6535            STORM: Frontline Nation       PC           2011.0  Strategy
#
#                          Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales
# 8           Microsoft Game Studios     15.00      4.89      0.24         1.69  \
# 15                      Activision      4.99      5.73      0.65         2.42
# 18                        Nintendo      5.03      4.02      2.69         0.91
# 19                      Activision      5.99      4.37      0.48         1.79
# 23                        Nintendo      4.89      3.00      2.14         0.78
# ...                            ...       ...       ...       ...          ...
# 6529               Milestone S.r.l      0.00      0.01      0.00         0.00
# 6531                      Nintendo      0.00      0.01      0.00         0.00
# 6533  Konami Digital Entertainment      0.00      0.01      0.00         0.00
# 6534                     Destineer      0.01      0.00      0.00         0.00
# 6535                       Unknown      0.00      0.01      0.00         0.00
#
#       Global_Sales  Critic_Score  Critic_Count  User_Score  User_Count
# 8            21.81          61.0          45.0         6.3       106.0  \
# 15           13.79          83.0          21.0         5.3       922.0
# 18           12.66          85.0          73.0         8.2       632.0
# 19           12.63          88.0          58.0         6.4      1094.0
# 23           10.81          90.0          82.0         8.4       921.0
# ...            ...           ...           ...         ...         ...
# 6529          0.01          63.0           8.0         8.2        22.0
# 6531          0.01          81.0          46.0         8.5       151.0
# 6533          0.01          80.0          20.0         7.6       412.0
# 6534          0.01          61.0          12.0         5.8        43.0
# 6535          0.01          60.0          12.0         7.2        13.0
#
#                                               Developer Rating
# 8                                   Good Science Studio      E
# 15                                             Treyarch      M
# 18    Retro Studios, Entertainment Analysis & Develo...      E
# 19                                             Treyarch      M
# 23                                             Nintendo      E
# ...                                                 ...    ...
# 6529                                    Milestone S.r.l      E
# 6531                                            Shin'en      E
# 6533                                 Kojima Productions      M
# 6534                                       Atomic Games      T
# 6535                                             SimBin   E10+
#
# [1987 rows x 16 columns]

# %%
# Top Platforms (Globally)
platforms = vg.groupby('Platform')['Global_Sales'].sum()
plt.figure(figsize=(20, 8))
sns.barplot(x = platforms.index, y = platforms.values)
plt.title('Top Video Game Platforms by Global Sales')
plt.xlabel('Platform')
plt.ylabel('Global Sales')
plt.show()

# %%
# Top Video Game Platforms by Global Sales in the 90s

platforms90 = vg90s.groupby('Platform')['Global_Sales'].sum()

plt.figure(figsize=(20, 8))
sns.barplot(x = platforms90.index, y = platforms90.values)
plt.title('Top Video Game Platforms by Global Sales in 90s')
plt.xlabel('Platform')
plt.ylabel('Global Sales')
plt.show()

# %%
# Top Video Game Platforms by Global Sales from 2000-2009

#Create DF from 2000-2009
vg00s = vg.loc[(vg["Year_of_Release"] >= 2000) & (vg["Year_of_Release"] < 2009)].copy()
platforms00 = vg00s.groupby('Platform')['Global_Sales'].sum()


plt.figure(figsize=(20, 8))
sns.barplot(x = platforms00.index, y = platforms00.values)
plt.title('Top Video Game Platforms by Global Sales from 2000-2009')
plt.xlabel('Platform')
plt.ylabel('Global Sales')
plt.show()

# %%
# Top Video Game Platforms by Global Sales from 2010-2016
platforms10 = vg10s.groupby('Platform')['Global_Sales'].sum()

plt.figure(figsize=(20, 8))
sns.barplot(x = platforms10.index, y = platforms10.values)
plt.title('Top Video Game Platforms by Global Sales in 2010s')
plt.xlabel('Platform')
plt.ylabel('Global Sales')
plt.show()

# %%
top_10_90s = vg90s[:10]
top_10_00s = vg00s[:10]
top_10_10s = vg10s[:10]

# %%
#Top 10 Highest Selling Games Globally in 90s
ax = sns.barplot(x = 'Name', y = "Global_Sales", data = top_10_90s, hue= "Developer")
ax.figure.set_size_inches(14, 9)
ax.set_title("Most Sold Video Games in 90s", fontsize = 18)
ax.set_ylabel('Global Sales (Millions)', fontsize = 18)
ax.set_xlabel('Games', fontsize = 18)
plt.xticks(rotation = 90)
plt.show()

# %%
#Top 10 Highest Selling Games Globally in 2000s
ax = sns.barplot(x = 'Name', y = "Global_Sales", data = top_10_00s, hue= "Developer")
ax.figure.set_size_inches(14, 9)
ax.set_title("Most Sold Video Games between 2000-2009", fontsize = 18)
ax.set_ylabel('Global Sales (Millions)', fontsize = 18)
ax.set_xlabel('Games', fontsize = 18)
plt.xticks(rotation = 90)
plt.show()

# %%
#Top 10 Highest Selling Games Globally in 2010s
ax = sns.barplot(x = 'Name', y = "Global_Sales", data = top_10_10s, hue= "Developer")
ax.figure.set_size_inches(14, 9)
ax.set_title("Most Sold Games in 2010s", fontsize = 28)
ax.set_ylabel('Global Sales (Millions)', fontsize = 18)
ax.set_xlabel('Games', fontsize = 18)
plt.xticks(rotation = 90)
plt.show()

# %%
# # Initialize the matplotlib figure
# f, ax = plt.subplots(figsize=(10, 6))



# # Plot the total sales
# sns.set_color_codes("pastel")
# sns.barplot(x="Global_Sales", y="Name", data=top_10_90s,
#             label="Total Sales (Global)", color = "lightgrey")

# # sns.set_color_codes("muted")
# sns.barplot(x="JP_Sales", y="Name", data=top_10_90s,
#             label="Japan", color='g')

# # Plot the crashes where alcohol was involved
# # sns.set_color_codes("muted")
# sns.barplot(x="NA_Sales", y="Name", data=top_10_90s,
#             label="North America", color='r')

# # sns.set_color_codes("muted")
# sns.barplot(x="EU_Sales", y="Name", data=top_10_90s,
#             label="Europe", color='orange')



# # Add a legend and informative axis label
# ax.legend(ncol=2, loc="lower right", frameon=True)
# ax.set(xlabel="Sales (in Millions)")

# plt.title("Top 10 Games Sold in 90s")
# # sns.despine(left=True, bottom=True)
